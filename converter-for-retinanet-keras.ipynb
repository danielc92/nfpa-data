# %%
import os

# %%
for filename in os.listdir('./absolute-271-text-files/'):
    
    with open('./absolute-271-text-files/' + filename, 'r') as f:
        data = f.read()
        f.close()
        
    split = data.split('\n')
    
    print('path/',filename.replace('.txt', '.jpg'),',',split[1].replace(' ',','),',class', sep="")
# Out:
# path/pos-251.jpg,84,36,264,212,class
# path/pos-279.jpg,968,609,1004,649,class
# path/pos-292.jpg,782,661,815,701,class
# path/pos-286.jpg,1050,459,1087,481,class
# path/pos-18.jpg,88,153,183,247,class
# path/pos-30.jpg,61,50,165,150,class
# path/pos-24.jpg,161,152,218,213,class
# path/pos-127.jpg,20,16,286,295,class
# path/pos-133.jpg,13,16,294,287,class
# path/pos-132.jpg,19,21,279,279,class
# path/pos-126.jpg,12,15,286,292,class
# path/pos-25.jpg,35,80,191,232,class
# path/pos-31.jpg,153,148,403,400,class
# path/pos-19.jpg,45,45,345,342,class
# path/pos-287.jpg,1136,817,1182,861,class
# path/pos-293.jpg,926,785,957,810,class
# path/pos-278.jpg,956,647,982,675,class
# path/pos-244.jpg,178,9,272,103,class
# path/pos-250.jpg,10,30,156,184,class
# path/pos-246.jpg,144,274,271,418,class
# path/pos-252.jpg,37,10,131,156,class
# path/pos-285.jpg,864,708,903,742,class
# path/pos-291.jpg,669,763,715,816,class
# path/pos-27.jpg,21,111,200,278,class
# path/pos-130.jpg,9,64,289,230,class
# ...

# %%
data
# Out:
# '1\n39 9 241 293\n'
